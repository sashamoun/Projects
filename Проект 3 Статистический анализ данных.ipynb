# %% [markdown]
# # Определение перспективного тарифа для телеком компании #
#
# ## Описание проекта ##
#
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
#
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.

# %% [markdown]
# ## Описание тарифов ##
#
# ## Тариф «Смарт» ##
# Ежемесячная плата: 550 рублей
#
# Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
#
# ### Стоимость услуг сверх тарифного пакета ###:
#
# минута разговора: 3 рубля
#
# сообщение: 3 рубля
#
# 1 Гб интернет-трафика: 200 рублей
#
# ## Тариф «Ультра» ##
# Ежемесячная плата: 1950 рублей
#
# Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
#
# ### Стоимость услуг сверх тарифного пакета: ###
#
# минута разговора: 1 рубль
#
# сообщение: 1 рубль
#
# 1 Гб интернет-трафика: 150 рублей

# %% [markdown]
# ## Описание данных ##
#
# ### Таблица users (информация о пользователях): ###
# - user_id — уникальный идентификатор пользователя
# - first_name — имя пользователя
# - last_name — фамилия пользователя
# - age — возраст пользователя (годы)
# - reg_date — дата подключения тарифа (день, месяц, год)
# - churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# - city — город проживания пользователя
# - tariff — название тарифного плана
#
# ### Таблица calls (информация о звонках): ###
# - id — уникальный номер звонка
# - call_date — дата звонка
# - duration — длительность звонка в минутах
# - user_id — идентификатор пользователя, сделавшего звонок
#
# ### Таблица messages (информация о сообщениях): ###
# - id — уникальный номер сообщения
# - message_date — дата сообщения
# - user_id — идентификатор пользователя, отправившего сообщение
#
# ### Таблица internet (информация об интернет-сессиях): ###
# - id — уникальный номер сессии
# - mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - session_date — дата интернет-сессии
# - user_id — идентификатор пользователя
#
# ### Таблица tariffs (информация о тарифах):  ###
# - tariff_name — название тарифа
# - rub_monthly_fee — ежемесячная абонентская плата в рублях
# - minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
# - messages_included — количество сообщений в месяц, включённых в абонентскую плату
# - mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# - rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# - rub_per_message — стоимость отправки сообщения сверх тарифного пакета
# - rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию  ###
#
# Путь к файлам:
#
# /datasets/calls.csv.
#
# /datasets/internet.csv.
#
# /datasets/messages.csv.
#
# /datasets/tariffs.csv.
#
# /datasets/users.csv.
#
# ### Шаг 2. Подготовьте данные ###
#
# - Приведите данные к нужным типам;
# - Найдите и исправьте ошибки в данных.
# - Поясните, какие ошибки вы нашли и как их исправили. Обратите внимание, что длительность многих звонков — 0.0 минут. Это могут быть пропущенные звонки. Обрабатывать ли эти нулевые значения, решать вам — оцените, как их отсутствие повлияет на результаты анализа.
# - Посчитайте для каждого пользователя:
# - количество сделанных звонков и израсходованных минут разговора по месяцам;
# - количество отправленных сообщений по месяцам;
# - объем израсходованного интернет-трафика по месяцам;
# - помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).
#
# ### Шаг 3. Проанализируйте данные ###
#
# - Опишите поведение клиентов оператора, исходя из выборки. Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц?
# - Посчитайте среднее количество, дисперсию и стандартное отклонение.
# - Постройте гистограммы.
# - Опишите распределения.
#
# ### Шаг 4. Проверьте гипотезы ###
#
# - средняя выручка пользователей тарифов «Ультра» и «Смарт» различается;
# - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов;
#
#
# ### Шаг 5. Напишите общий вывод ###

# %% [markdown]
# ## Этап 1. Предобработка данных

# %% [markdown]
# ### Задачи:
#     1. Импортировать библиотеки;
#     2. Открыть файлы;
#     3. Изучить общую информацию о файлах;
#     4. Заполнение пропусков.
#     5. Изменение типов данных (где требуется).

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться с тем о чем сам проект. Можно также привести описание используемых столбцов.
#
# </div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from datetime import datetime 
from scipy import stats as st
import plotly.express as px

# %%
users = pd.read_csv('/datasets/users.csv')
calls = pd.read_csv('/datasets/calls.csv')
messages = pd.read_csv('/datasets/messages.csv')
internet = pd.read_csv('/datasets/internet.csv')
tariffs = pd.read_csv('/datasets/tariffs.csv')

# %% [markdown]
# ### Файл 1: пользователи

# %%
users.head()
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %%
users.describe()
# Out:
#            user_id        age
# count   500.000000  500.00000
# mean   1249.500000   46.58800
# std     144.481833   16.66763
# min    1000.000000   18.00000
# 25%    1124.750000   32.00000
# 50%    1249.500000   46.00000
# 75%    1374.250000   62.00000
# max    1499.000000   75.00000

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null object
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null object
# tariff        500 non-null object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# Данный файл содержит в себе информацию по 500 пользователям: (id, возраст, город, фамилия и имя, дата регистрации, выбранный тариф и дата прекращения пользования тарифом). Пропусков нет, за исключением столбца с датой прекращения пользования тарифом. Там заполнено только 38 строк. Следовательно, 38 пользователей перестали пользоваться тарифом за отчетный период, а остальные 462 пользователя все еще используют 1 из 2 тарифов. В данном случае пропуски заполнять не нужно. Сразу видно, что не все данные приведены в нужном виде. Дату регистрации и дату прекращение пользования тарифом необходимо перевести в формат дата-время.

# %%
users['churn_date'] = pd.to_datetime(users['churn_date'], format="%Y-%m-%d")
users['reg_date'] = pd.to_datetime(users['reg_date'], format="%Y-%m-%d")
users.info()
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null datetime64[ns]
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null datetime64[ns]
# tariff        500 non-null object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# ...

# %% [markdown]
# Выставили тип данных правильно.

# %% [markdown]
# ### Файл 2: Звонки

# %%
calls.head(10)
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
# 5  1000_5  2018-11-02      0.00     1000
# 6  1000_6  2018-10-18      0.00     1000
# 7  1000_7  2018-08-22     18.31     1000
# 8  1000_8  2018-09-15     18.44     1000
# 9  1000_9  2018-08-15      0.00     1000

# %%
calls.describe()
# Out:
#             duration        user_id
# count  202607.000000  202607.000000
# mean        6.755887    1253.940619
# std         5.843365     144.722751
# min         0.000000    1000.000000
# 25%         1.300000    1126.000000
# 50%         6.000000    1260.000000
# 75%        10.700000    1379.000000
# max        38.000000    1499.000000

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null object
# duration     202607 non-null float64
# user_id      202607 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# Данный файл содержит 202607 записей - информация о звонках: айди пользователя, айди звонка, длительность звонка, дата звонка.
# Пропусков нет. Типы данных с датой также надо перевести в нужный формат дата-время. Айди звонка тоже удобно будет перевести в формат целочисленных значений. Если неполная минута, то по стоимости операторы считают, что клиент говорил минуту, поэтому округляем до ближайшего верхнего значения и делаем целочисленный тип.

# %%
calls['call_date'] = pd.to_datetime(calls['call_date'], format="%Y-%m-%d")

calls['id'] = calls['id'].astype('int')

calls['duration'] = calls['duration'].apply(np.ceil).astype('int')

calls.head()
# Out:
#       id  call_date  duration  user_id
# 0  10000 2018-07-25         0     1000
# 1  10001 2018-08-17         0     1000
# 2  10002 2018-06-11         3     1000
# 3  10003 2018-09-21        14     1000
# 4  10004 2018-12-15         6     1000

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Хорошо, что учитываем условия работы оператора связи и применяем метод `np.ceil`.
# </div>

# %% [markdown]
# Теперь таблица более понятная и правильная, но все же есть нулевые значения по параметру длительность. Есть предположение, что эти звонки длились от 0 до 1 минуты и округлились в меньшую сторону, следовательно, можно заменить их на 1. (Возможно, что это звонки до 30 сек округлялись в сторону 0, а больше 30 сек в сторону 1. Еще, конечно, возможно, что это те звонки, на которые не отвечали, но тогда, скорее всего, их бы не заносили в реестр, т.к. за такие звонки не берется плата и не тратится пакет бесплатных звонков, поэтому этот вариант маловероятен.) Соответственно, заполняем эти 0 на 1.

# %%
calls['duration'] = calls['duration'].replace(0, 1)


calls.describe()
# Out:
#                  id       duration        user_id
# count  2.026070e+05  202607.000000  202607.000000
# mean   1.212254e+06       7.353714    1253.940619
# std    1.725756e+06       5.733230     144.722751
# min    1.000000e+04       1.000000    1000.000000
# 25%    1.012286e+06       2.000000    1126.000000
# 50%    1.179376e+06       6.000000    1260.000000
# 75%    1.358126e+06      11.000000    1379.000000
# max    1.458115e+07      38.000000    1499.000000

# %% [markdown]
# Теперь у нас минимальное значение по длительности - 1.

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null int64
# call_date    202607 non-null datetime64[ns]
# duration     202607 non-null int64
# user_id      202607 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 6.2 MB

# %% [markdown]
# Типы данных выставлены правильно.

# %% [markdown]
# ### Файл 3: Сообщения

# %%
messages.head()
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null object
# user_id         123036 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# Данные содержат информацию о 123035 сообщениях (айди сообщения, дата сообщения, айди пользователя). Пропусков нет. Типы данных изменяем в поле айди сообщения и даты сообщения.

# %%
messages['id'] = messages['id'].astype('int')
messages['message_date'] = pd.to_datetime(messages['message_date'], format="%Y-%m-%d")
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null int64
# message_date    123036 non-null datetime64[ns]
# user_id         123036 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 2.8 MB

# %% [markdown]
# ### Файл 4: Интернет

# %%
internet.head(10)
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000
# 5           5  1000_5   399.97   2018-10-02     1000
# 6           6  1000_6   540.08   2018-09-07     1000
# 7           7  1000_7   415.70   2018-07-11     1000
# 8           8  1000_8   505.40   2018-10-08     1000
# 9           9  1000_9   345.54   2018-09-03     1000

# %%
internet.describe()
# Out:
#           Unnamed: 0        mb_used        user_id
# count  149396.000000  149396.000000  149396.000000
# mean    74697.500000     370.192426    1252.099842
# std     43127.054745     278.300951     144.050823
# min         0.000000       0.000000    1000.000000
# 25%     37348.750000     138.187500    1130.000000
# 50%     74697.500000     348.015000    1251.000000
# 75%    112046.250000     559.552500    1380.000000
# max    149395.000000    1724.830000    1499.000000

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
# Unnamed: 0      149396 non-null int64
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null object
# user_id         149396 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %% [markdown]
# В файле 4 хранятся данные о пользовании интернетом (айди сессии, количество использованных мбайт, дата сессии, айди пользователя). Здесь вылез очень странный столбец, который обозначился Unnamed - по сути это просто порядковый номер наблюдений. В самом файле первая строка начинается с "," (", id, mb_used,	session_date,	user_id"), т.е. пропустили название первого столбца. Отсюда и эта ошибка. Я дума, что нам вполне можно удалить этот столбец, т.к. в пандас все равно идет нумерация, а также есть столбец с айди сессии. Но если все же удалять столбец не требуется, то лучше его переименовать. Я проверил оба  способа, они работают, но пока удалил этот столбец, а с переименованием закомментировал. (могу изменить если потребуется)

# %%
internet = internet.drop(['Unnamed: 0'], axis=1)
#internet = internet.rename(columns={'Unnamed: 0': '№'})
internet.head(10)
# Out:
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000
# 5  1000_5   399.97   2018-10-02     1000
# 6  1000_6   540.08   2018-09-07     1000
# 7  1000_7   415.70   2018-07-11     1000
# 8  1000_8   505.40   2018-10-08     1000
# 9  1000_9   345.54   2018-09-03     1000

# %%
internet['id'] = internet['id'].astype('int')
#internet['session_date'] = pd.to_datetime(internet['session_date'], format="%Y-%m-%d")
internet.head()
# Out:
#       id  mb_used session_date  user_id
# 0  10000   112.95   2018-11-25     1000
# 1  10001  1052.81   2018-09-07     1000
# 2  10002  1197.26   2018-06-25     1000
# 3  10003   550.27   2018-08-22     1000
# 4  10004   302.56   2018-09-24     1000

# %% [markdown]
# Изменил тип данных у айди сессии и даты сессии.

# %% [markdown]
# ### Файл 5: Тарифы

# %%
tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %%
tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
# messages_included        2 non-null int64
# mb_per_month_included    2 non-null int64
# minutes_included         2 non-null int64
# rub_monthly_fee          2 non-null int64
# rub_per_gb               2 non-null int64
# rub_per_message          2 non-null int64
# rub_per_minute           2 non-null int64
# tariff_name              2 non-null object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# В этом файле хранятся данные по двум тарифам, пакете включенных услуг и стомости. Пропусков нет, все типы данных указаны верно.

# %% [markdown]
# ## Заключение по этапу 1.##
# Таким образом, я перевел типы данных в нужный формат, пропусков, которые необходимо заполнять не было. Значения в длительности звонков подкорректированы в соответствии с логикой работы операторов связи (изменил 0 на 1).

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Достаточно детально изучили наши первичные данные, давай теперь их подготовим.
#
#
#
# </div>

# %% [markdown]
# ## Этап 2. Подготовка данных.##
# ### Задачи:###
# Посчитать для каждого пользователя:
# 1. количество сделанных звонков и израсходованных минут разговора по месяцам;
# 2. количество отправленных сообщений по месяцам;
# 3. объем израсходованного интернет-трафика по месяцам;
# 4. помесячную выручку с каждого пользователя.

# %% [markdown]
# ### Задача 1: Посчитать количество сделанных звонков и израсходованных минут разговора по месяцам###

# %%
calls['month'] = calls['call_date'].dt.month_name()
calls.head()
# Out:
#       id  call_date  duration  user_id      month
# 0  10000 2018-07-25         1     1000       July
# 1  10001 2018-08-17         1     1000     August
# 2  10002 2018-06-11         3     1000       June
# 3  10003 2018-09-21        14     1000  September
# 4  10004 2018-12-15         6     1000   December

# %%
user_calls = calls.groupby(['user_id', 'month'])\
                  .agg({'duration':'sum', 'id':'count'})\
                  .reset_index()\
                  .rename(columns={'duration':'month_calls_duration','id':'total_amount_of_calls_in_month'})

user_calls.head()
# Out:
#    user_id     month  month_calls_duration  total_amount_of_calls_in_month
# 0     1000    August                   418                              52
# 1     1000  December                   341                              46
# 2     1000      July                   346                              47
# 3     1000      June                   187                              43
# 4     1000       May                   164                              22

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Группировкой мы пользоваться научились, и это здорово.
#
# Это инструмент мы будем использовать достаточно часто, чтобы решить часть задач.
#
# </div>

# %% [markdown]
# Создаю новый столбец с месяцем. Далее группирую данные по айди пользователя и месяцам, чтобы узнать сколько всего сделано звонков тем или иным пользователем за месяц, а также какая общая длительность этих звонков. ( 2-3 задачи аналогичным способом)

# %% [markdown]
# ### Задача 2: Посчитать количество отправленных сообщений по месяцам.###

# %%
messages['month'] = messages['message_date'].dt.month_name()
messages.head()
# Out:
#       id message_date  user_id     month
# 0  10000   2018-06-27     1000      June
# 1  10001   2018-10-08     1000   October
# 2  10002   2018-08-04     1000    August
# 3  10003   2018-06-16     1000      June
# 4  10004   2018-12-05     1000  December

# %%
user_messages = messages.groupby(['user_id', 'month'])\
                        .agg({'id':'count'})\
                        .reset_index()\
                        .rename(columns={'id':'total_amount_of_sms_in_month'})

user_messages.head()
# Out:
#    user_id     month  total_amount_of_sms_in_month
# 0     1000    August                            81
# 1     1000  December                            70
# 2     1000      July                            75
# 3     1000      June                            60
# 4     1000       May                            22

# %% [markdown]
# ### Задача 3: Посчитать объем израсходованного интернет-трафика по месяцам.###

# %%
internet['session_date'] = pd.to_datetime(internet['session_date'], format="%Y-%m-%d")
internet['month'] = internet['session_date'].dt.month_name()

internet.head()
# Out:
#       id  mb_used session_date  user_id      month
# 0  10000   112.95   2018-11-25     1000   November
# 1  10001  1052.81   2018-09-07     1000  September
# 2  10002  1197.26   2018-06-25     1000       June
# 3  10003   550.27   2018-08-22     1000     August
# 4  10004   302.56   2018-09-24     1000  September

# %%
user_internet = internet.groupby(['user_id', 'month'])\
                        .agg({'mb_used':'sum'})\
                        .reset_index()\
                        .rename(columns={'mb_used':'total_amount_of_mb_in_month'})

user_internet.head()
# Out:
#    user_id     month  total_amount_of_mb_in_month
# 0     1000    August                     14055.93
# 1     1000  December                      9817.61
# 2     1000      July                     14003.64
# 3     1000      June                     23233.77
# 4     1000       May                      2253.49

# %% [markdown]
# ### Задача 4: Посчитать помесячную выручку с каждого пользователя.###

# %% [markdown]
# Сделаем таблицу со всеми полученными данными

# %%
df = user_calls.merge(user_messages, on=['user_id','month'], how='outer')
df = df.merge(user_internet, on=['user_id','month'], how = 'outer')

df.head()
# Out:
#    user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 0     1000    August                 418.0                            52.0
# 1     1000  December                 341.0                            46.0
# 2     1000      July                 346.0                            47.0
# 3     1000      June                 187.0                            43.0
# 4     1000       May                 164.0                            22.0
#
#    total_amount_of_sms_in_month  total_amount_of_mb_in_month
# 0                          81.0                     14055.93
# 1                          70.0                      9817.61
# 2                          75.0                     14003.64
# 3                          60.0                     23233.77
# 4                          22.0                      2253.49

# %% [markdown]
# Вот здесь есть небольшой вопрос. Правильно ли я выбрал параметр ‘how’? Я почитал, что outer – это полное пересечение, т.е. будут включены все клиенты, которые либо делали звонки, либо писали смс, либо пользовались интернетом, включая все пересечения этих видов услуг. Как я понимаю, нам здесь как раз надо найти охватить всех клиентов, т.к. некоторые могут не пользоваться какой-либо из функций, и если использовать left или right, то они окажутся за бортом нашего датасета.

# %% [markdown]
# Далее надо добавить тариф клиентов из таблицы users

# %%
users.head()

df = df.merge(users, on='user_id', how='left')
df.head()
# Out:
#    user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 0     1000    August                 418.0                            52.0
# 1     1000  December                 341.0                            46.0
# 2     1000      July                 346.0                            47.0
# 3     1000      June                 187.0                            43.0
# 4     1000       May                 164.0                            22.0
#
#    total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# 0                          81.0                     14055.93   52        NaT
# 1                          70.0                      9817.61   52        NaT
# 2                          75.0                     14003.64   52        NaT
# 3                          60.0                     23233.77   52        NaT
# 4                          22.0                      2253.49   52        NaT
#
# ...

# %% [markdown]
# Как я понял, в этом случае нам надо ставить в параметр ‘how’ = ‘left’, т.к. мы присоединяем название тарифа к каждому пользователю в нашем созданном датасете. (Кстати, а если бы здесь мы ввели outer, и у нас бы наш датафрейм состоял из Пети, Маши, Васи и в таблице users были бы тоже только Петя, Маша, Вася, то тогда же все бы совпало без добавления лишних? Если я правильно усвоил этот материал, то добавления или наоборот исключения тех или иных строк в случаях, когда мы ставим ‘left’/’right’ происходит только при условии, что эти таблицы не полностью совпадают по интересующим нас параметрам. А если они совпадают, то можно ставить просто ‘outer’. Если я в этих рассуждениях ошибся поправь, пожалуйста, просто с пересечениями этими немного трудновато было понять.)

# %%
tariffs = tariffs.rename(columns={'tariff_name':'tariff'})
tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff
# 0              550         200                3               3  smart
# 1             1950         150                1               1  ultra

# %%
#df = df.merge(tariffs, on='tariff_name', how='left') 
df = df.merge(tariffs, on='tariff', how='left') 

df.head(10)
# Out:
#    user_id      month  month_calls_duration  total_amount_of_calls_in_month  \
# 0     1000     August                 418.0                            52.0
# 1     1000   December                 341.0                            46.0
# 2     1000       July                 346.0                            47.0
# 3     1000       June                 187.0                            43.0
# 4     1000        May                 164.0                            22.0
# 5     1000   November                 344.0                            43.0
# 6     1000    October                 363.0                            57.0
# 7     1000  September                 478.0                            58.0
# 8     1001   December                 430.0                            63.0
# 9     1001   November                 444.0                            59.0
#
#    total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# ...

# %% [markdown]
# Добавил здесь информацию о стоимости из таблицы тарифов. Здесь тоже небольшой вопрос. Если название столбцов не совпадают у таблиц, которые мы хотим мерджить, то обязательно надо переименовать их? Или есть какой-то иной способ сделать так, чтобы таблица объединялась и учитывала значение "tariff_name" в таблице пользователей, как "tariff" из таблицы тарифов? Пока что сделал через переименование.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# В целом таблицы мы соединили верно.
#
#
#
# </div>

# %%
print(f'Количество клиентов: {df.user_id.nunique()}')
# Out:
# Количество клиентов: 498

# %% [markdown]
# ### Проверка пропусков

# %%
df.isna().sum()
# Out:
# user_id                              0
# month                                0
# month_calls_duration                40
# total_amount_of_calls_in_month      40
# total_amount_of_sms_in_month       497
# total_amount_of_mb_in_month         11
# age                                  0
# churn_date                        3027
# city                                 0
# first_name                           0
# last_name                            0
# reg_date                             0
# tariff                               0
# messages_included                    0
# mb_per_month_included                0
# minutes_included                     0
# rub_monthly_fee                      0
# rub_per_gb                           0
# rub_per_message                      0
# rub_per_minute                       0
# dtype: int64

# %% [markdown]
# Пропуски в некоторых местах есть, но их можно объяснить:
# 1. month_calls_duration и total_amount_of_calls_in_month - 40 пользователей ни разу не пользовались звонками за месяц.
# 2. total_amount_of_sms_in_month - 497 пользователей не отправили ни 1 смс сообщения за месяцю.
# 3. total_amount_of_mb_in_month - 11 пользователей ни разу не заходили в интернет за месяц.
# 4. churn_date - показатель, что пользователи продолжают использовать тариф.
#
# Думаю, здесь первые 3 пропуска логично просто заполнить нулями, а 4, наверное, пока оставим без изменений.

# %%
df['total_amount_of_sms_in_month'] = df['total_amount_of_sms_in_month'].fillna(0)
df['total_amount_of_mb_in_month'] = df['total_amount_of_mb_in_month'].fillna(0)
df['month_calls_duration'] = df['month_calls_duration'].fillna(0)
df['total_amount_of_calls_in_month'] = df['total_amount_of_calls_in_month'].fillna(0)

df.isna().sum()
# Out:
# user_id                              0
# month                                0
# month_calls_duration                 0
# total_amount_of_calls_in_month       0
# total_amount_of_sms_in_month         0
# total_amount_of_mb_in_month          0
# age                                  0
# churn_date                        3027
# city                                 0
# first_name                           0
# last_name                            0
# reg_date                             0
# tariff                               0
# messages_included                    0
# mb_per_month_included                0
# minutes_included                     0
# rub_monthly_fee                      0
# rub_per_gb                           0
# rub_per_message                      0
# rub_per_minute                       0
# dtype: int64

# %% [markdown]
# Теперь мы избавились от лишних пропусков.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет, значит, "смерджили" правильно и один, и записи об использовании тарифа пользователями не попали в наш датафрейм дважды (там есть именно повторения пользователей, например, вот в последней таблице Рафаил	Верещагин встречается 8 раз, но это записи за разные месяцы).

# %% [markdown]
# ### Задача 5: рассчитать помесячную выручку каждого из тарифов.

# %%
def above_the_tariff(row):
    sms = (row['total_amount_of_sms_in_month'] - row['messages_included']) * row['rub_per_message']
    mins = (row['month_calls_duration'] - row['minutes_included']) * row['rub_per_minute']
    mbs = np.floor((row['total_amount_of_mb_in_month'] - row['mb_per_month_included']) * row['rub_per_gb'] / 1024)
    total = 0
    for i in [sms, mins, mbs]:
        if i > 0:
            total += i
    return total
df['above_the_tariff'] = df.apply(above_the_tariff, axis=1)
df['total_paid'] = df['rub_monthly_fee'] + df['above_the_tariff']
df.sort_values(by='total_paid', ascending=False).head(10)
# Out:
#       user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 3104     1486  December                1025.0                           133.0
# 1620     1261  December                1102.0                           141.0
# 259      1042  December                 755.0                           121.0
# 3105     1486  November                 788.0                           108.0
# 1792     1286  December                 751.0                            95.0
# 999      1159  December                 759.0                           110.0
# 610      1098  December                 605.0                            80.0
# 783      1124   October                1247.0                           152.0
# 1621     1261  November                 773.0                           117.0
# 1494     1240    August                 462.0                            54.0
#
#       total_amount_of_sms_in_month  total_amount_of_mb_in_month  age  \
# ...

# %% [markdown]
# Создаю цикл, который будет применяться к каждой строке моего датафрейма.
# В этом цикле надо найти превышает ли пользователь лимит по смс, минутам, Мбайтам. Рассчитывается по формуле ("сколько клиент потратил" - "сколько доступно в тарифе") * цену за единицу (минуту, смс, Мбайт) превышенного трафика. (В случае с интернетом надо еще разделить на 1024, т.к. в таблице с описанием цен тарифа указана цена за 1 Гбайт, а не Мбайт). Если превышается лимит, по какому-то из параметров, то стоимость пользования сверхлимита передается в счетчик 'total'. Далее создаю новый столбец в датафрейме "above_the_tariff", где будет указана стоимость сверх тарифа. Чтобы найти общую стоимость создаю новый столбец 'total_paid', где складываю ежемесячную плату по тарифу и ту плату, которую заплатил клиент за превышение тарифа. Как видно из отсортированной таблицы, самые общительные клиенты значительно превышают этот лимит и платят  от 4532 до 6753 рублей за месяц. (первая десятка)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выручка посчитана верно.
# </div>

# %% [markdown]
# ### Заключение по этапу 2.###
# Теперь наш датафрейм - это не просто отдельный набор данных о звонках, сообщениях или пользовании интернетом, а единая база, которая содержит всю информацию о каждом пользователе по месяцам. В таком виде можно начинать анализ поведения пользователей и тарифов.

# %% [markdown]
# ## Этап 3. Анализ данных.##

# %% [markdown]
# ### Задачи:  ###
# 1. Описать поведение клиентов оператора, исходя из выборки.
# 2. Ответить на вопросы: Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц?
# 3. Посчитать среднее количество, дисперсию и стандартное отклонение.
# 4. Построить гистограммы.
# 5. Описать распределения.

# %% [markdown]
# ###  Задача 1. Описать поведение клиентов оператора, исходя из выборки. ###

# %%
df.describe()
# Out:
#            user_id  month_calls_duration  total_amount_of_calls_in_month  \
# count  3214.000000           3214.000000                     3214.000000
# mean   1251.590230            463.570006                       63.038892
# std     144.659172            247.918544                       33.236368
# min    1000.000000              0.000000                        0.000000
# 25%    1125.000000            291.000000                       40.000000
# 50%    1253.000000            456.000000                       62.000000
# 75%    1378.750000            605.000000                       82.000000
# max    1499.000000           1727.000000                      244.000000
#
#        total_amount_of_sms_in_month  total_amount_of_mb_in_month          age  \
# count                   3214.000000                  3214.000000  3214.000000
# mean                      38.281269                 17207.612859    46.641568
# ...

# %% [markdown]
# По данной таблице можно описать поведение клиентов двух тарифов.
# 1. Медианное и среднее значение по длительности звонков в месяц не сильно отличается: 456 и 463 минуты соответственно. Встречаются некоторые выбросы: например, те люди, которые вообще не пользовались звонками за месяц (я заполнял пропуски на 0 ранее), а также те, кто очень много говорил - 1727 минут за месяц - наибольшая длительность звонков за месяц.
# 2. По количеству звонков в среднем клиенты делали 62-63 звонка за месяц (медианное и среднее значение).
# 3. Среднее количество смс сообщений в месяц - 38, что уже достаточно существенно отличается от медианного значения в 30 сообщений, следовательно, здесь распределение сместилось влево от нормального распределения (более пологий правый ус).
# 4. По количеству использованных Мбайт в среднем используют 17208 мбайт.
# 5. Средний возраст клиентов данного оператора - 46 лет.
# 6. В среднем переплачивают сверх тарифа 517 рублей, но медианное значение - 123 рубля. Это значит, что большинство укладывается в отведенное количество минут, смс сообщений и Мбайт.
# 7. Средняя общая плата (за сам тариф + превышение лимита) - 1496 рублей - это даже ниже медианного значения (1584 рубля).

# %%
print(df.groupby('tariff')['user_id'].count())
# Out:
# tariff
# smart    2229
# ultra     985
# Name: user_id, dtype: int64

# %% [markdown]
# Здесь также интересно посмотреть сколько в нашей выборке пользователей каждого из тарифов.

# %% [markdown]
# ### Сделаем 2 среза для каждого из тарифов и ответим на вопросы поставленные в задаче 2.###

# %%
unltra_tar = df.query('tariff == "ultra"')
smart_tar = df.query('tariff == "smart"')

# %%
unltra_tar.head(10)
# Out:
#     user_id      month  month_calls_duration  total_amount_of_calls_in_month  \
# 0      1000     August                 418.0                            52.0
# 1      1000   December                 341.0                            46.0
# 2      1000       July                 346.0                            47.0
# 3      1000       June                 187.0                            43.0
# 4      1000        May                 164.0                            22.0
# 5      1000   November                 344.0                            43.0
# 6      1000    October                 363.0                            57.0
# 7      1000  September                 478.0                            58.0
# 17     1003     August                 392.0                            55.0
# 18     1003   December                 822.0                           108.0
#
#     total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# ...

# %%
smart_tar.head(10)
# Out:
#     user_id      month  month_calls_duration  total_amount_of_calls_in_month  \
# 8      1001   December                 430.0                            63.0
# 9      1001   November                 444.0                            59.0
# 10     1002     August                 294.0                            42.0
# 11     1002   December                 242.0                            33.0
# 12     1002       July                 219.0                            26.0
# 13     1002       June                 118.0                            15.0
# 14     1002   November                 250.0                            32.0
# 15     1002    October                 221.0                            33.0
# 16     1002  September                 217.0                            36.0
# 30     1005      April                 736.0                           101.0
#
#     total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# ...

# %% [markdown]
# Готово, теперь можно приступить к анализу тарифов по отдельности.

# %% [markdown]
# ### Анализ тарифа "unltra". ###

# %%
unltra_tar.describe()
# Out:
#            user_id  month_calls_duration  total_amount_of_calls_in_month  \
# count   985.000000            985.000000                      985.000000
# mean   1263.094416            540.779695                       73.392893
# std     140.694908            325.738740                       43.916853
# min    1000.000000              0.000000                        0.000000
# 25%    1143.000000            292.000000                       41.000000
# 50%    1277.000000            532.000000                       74.000000
# 75%    1381.000000            773.000000                      104.000000
# max    1495.000000           1727.000000                      244.000000
#
#        total_amount_of_sms_in_month  total_amount_of_mb_in_month         age  \
# count                    985.000000                   985.000000  985.000000
# mean                      49.363452                 19468.805208   46.834518
# std                       47.804457                 10087.170752   17.107979
# ...

# %% [markdown]
# В среднем пользователи тарифа "ультра" тратят в месяц 541 минуту на разговоры, отправляют 49 сообщений и используют 19469 Мбайт интернета. Если взять более устойчивую к выбросам меру среднего - медиану, то, соответственно, получим цифры 532, 38 и 19308. Здесь видно, что значительно эти параметры отличаются только по количеству смс сообщений. В среднем переплачивают сверх ежемесячной платы 110 рублей, но более показательно, что медиана и даже третий квартиль (75%) - 0, следовательно, очень малое количество пользователей смарт превышают ежемесячный лимит. Это же подтверждает и общая плата клиентов - 1950 рублей - это ежемесячный платеж за тариф "ультра".

# %% [markdown]
# ### Анализ тарифа "smart". ###

# %%
smart_tar.describe()
# Out:
#            user_id  month_calls_duration  total_amount_of_calls_in_month  \
# count  2229.000000           2229.000000                     2229.000000
# mean   1246.506505            429.450875                       58.463437
# std     146.119496            194.871174                       25.939858
# min    1001.000000              0.000000                        0.000000
# 25%    1121.000000            291.000000                       40.000000
# 50%    1239.000000            435.000000                       60.000000
# 75%    1376.000000            560.000000                       76.000000
# max    1499.000000           1471.000000                      198.000000
#
#        total_amount_of_sms_in_month  total_amount_of_mb_in_month          age  \
# count                   2229.000000                  2229.000000  2229.000000
# mean                      33.384029                 16208.386990    46.556303
# ...

# %% [markdown]
# В среднем пользователи тарифа "смарт" тратят в месяц 429 минут на разговоры, отправляют 33 сообщения и используют 16208 Мбайт интернета. Медианные значения, соответственно равны - 435, 28 и 16507. Наиболее сильно отличается опять же параметр смс сообщений в месяц. С цифрами, касающимися оплаты здесь интереснее. В среднем превышают лимит на сумму 697 рублей. При этом медианное значение этого показателя 433 рубля, что говорит о том, что многие пользователи этого тарифа превышают лимит. Только чуть меньше 25% укладываются в рамки лимита (первый квартиль 25% - превышение на 2 рубля). Общая плата - те же цифры только еще добавляется ежемесячная плата за сам тариф.

# %% [markdown]
# ### Среднее количество, дисперсия и стандартное отклонение для каждого из тарифов. ###

# %%
df.groupby('tariff').agg({'month_calls_duration':['median','mean','var','std']})
# Out:
#        month_calls_duration
#                      median        mean            var         std
# tariff
# smart                 435.0  429.450875   37974.774628  194.871174
# ultra                 532.0  540.779695  106105.726823  325.738740

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отличный способ посчитать нужные нам метрики 👍
#
# </div>

# %%
df.groupby('tariff').agg({'total_amount_of_calls_in_month':['median','mean','var','std']})
# Out:
#        total_amount_of_calls_in_month
#                                median       mean          var        std
# tariff
# smart                            60.0  58.463437   672.876243  25.939858
# ultra                            74.0  73.392893  1928.689990  43.916853

# %%
df.groupby('tariff').agg({'total_amount_of_sms_in_month':['median','mean','var','std']})
# Out:
#        total_amount_of_sms_in_month
#                              median       mean          var        std
# tariff
# smart                          28.0  33.384029   796.812958  28.227876
# ultra                          38.0  49.363452  2285.266143  47.804457

# %%
df.groupby('tariff').agg({'total_amount_of_mb_in_month':['median','mean','var','std']})
# Out:
#        total_amount_of_mb_in_month
#                             median          mean           var           std
# tariff
# smart                     16506.84  16208.386990  3.446250e+07   5870.476681
# ultra                     19308.01  19468.805208  1.017510e+08  10087.170752

# %%
df.groupby('tariff').agg({'above_the_tariff':['median','mean','var','std']})
# Out:
#        above_the_tariff
#                  median        mean            var         std
# tariff
# smart             433.0  697.131898  631904.589417  794.924266
# ultra               0.0  109.800000  125843.213008  354.743870

# %%
df.groupby('tariff').agg({'total_paid':['median','mean','var','std']})
# Out:
#        total_paid
#            median         mean            var         std
# tariff
# smart       983.0  1247.131898  631904.589417  794.924266
# ultra      1950.0  2059.800000  125843.213008  354.743870

# %% [markdown]
# Получили среднее количество, дисперсию и стандартное отклонение для каждого из тарифов по интересующим нас параметрам. В цифрах, возможно, не очень наглядно смотрится, поэтому переходим к следующей задаче - строим графики распределения.

# %%
df[df['tariff'] == 'ultra']['month_calls_duration'].plot(kind='hist', bins=50)
plt.title('Распределение длительности звонков в месяц тарифа "ultra"') 
plt.xlabel('Длительность звонков') 
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда график и его оси подписаны 😊👍
#
# Так быстрее понять о чем идёт речь на самом графике.
#
# </div>

# %%
df[df['tariff'] == 'smart']['month_calls_duration'].plot(kind='hist', bins=30)
plt.title('Распределение длительности звонков в месяц тарифа "smart"') 
plt.xlabel('Длительность звонков') 
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Если сравнивать длительность звонков в месяц двух тарифов, то в случае с тарифом "smart" график более похож на нормальное распределение. В графике "ultra" есть несколько пиков (например, первый пик около 0, также есть пики около 250, 300, 500,750 и 850).

# %%
df[df['tariff'] == 'ultra']['total_amount_of_calls_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества звонков в месяц тарифа "ultra"') 
plt.xlabel('Количество звонков') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'smart']['total_amount_of_calls_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества звонков в месяц тарифа "smart"') 
plt.xlabel('Количество звонков') 
plt.ylabel('Частота')
plt.show()

# %%
display(df.pivot_table(index = 'tariff', values = ['month_calls_duration','total_amount_of_calls_in_month'], aggfunc = 'corr'))
# Out:
#                                        month_calls_duration  \
# tariff
# smart  month_calls_duration                        1.000000
#        total_amount_of_calls_in_month              0.974440
# ultra  month_calls_duration                        1.000000
#        total_amount_of_calls_in_month              0.989073
#
#                                        total_amount_of_calls_in_month
# tariff
# smart  month_calls_duration                                  0.974440
#        total_amount_of_calls_in_month                        1.000000
# ultra  month_calls_duration                                  0.989073
#        total_amount_of_calls_in_month                        1.000000

# %% [markdown]
# По количеству звонков в месяц графики похожи на продолжительность звонков, что логично, т.к. связь между этими двумя параметрами прямая, а корреляция почти равна 1.

# %%
df[df['tariff'] == 'ultra']['total_amount_of_sms_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества смс-сообщений в месяц тарифа "ultra"') 
plt.xlabel('Количество смс-сообщений') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'smart']['total_amount_of_sms_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества смс-сообщений в месяц тарифа "smart"') 
plt.xlabel('Количество смс-сообщений') 
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# В обоих тарифах пик приходится на 0. Медианное значение у "smart" и "ultra" 28 и 38 соответственно, а среднее значение -  33 и 49. Если сравнить эти цифры с тем, сколько смс в месяц доступно, то у тарифа "smart" - это 50 смс в месяц, а у тарифа "ultra" - 1000. Соответственно, средний пользователь тарифа "smart" тратит половину доступных ему сообщений, а тарифа "ultra" - менее 5%.

# %%
df[df['tariff'] == 'ultra']['total_amount_of_mb_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества потраченных Мбайт в месяц тарифа "ultra"') 
plt.xlabel('Количество потраченных Мбайт') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'smart']['total_amount_of_mb_in_month'].plot(kind='hist', bins=30)
plt.title('Распределение количества потраченных Мбайт в месяц тарифа "smart"') 
plt.xlabel('Количество потраченных Мбайт') 
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Среднее использование интернета в тарифах "ultra" и "smart" - 19308 и 16506 Мбайт соответственно. Медианные значения практически совпадают со средними, а сами графики похожи на нормальное распределение. В тарифе "ultra" в месяц дается 30 Гбайт, а в "smart" - 15 Гбайт, т.е. опять же пользователи тарифа ультра в большинстве случаях укладываются в отведенное количества Гбайт, а у пользователей смарт больше половины доплачивает за интернет.

# %%
df[df['tariff'] == 'ultra']['above_the_tariff'].plot(kind='hist', bins=30)
plt.title('Дополнительная плата за пользование услугами сверх тарифа "ultra"') 
plt.xlabel('Дополнительная плата') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'smart']['above_the_tariff'].plot(kind='hist', bins=30)
plt.title('Дополнительная плата за пользование услугами сверх тарифа "smart"') 
plt.xlabel('Дополнительная плата') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'ultra']['total_paid'].plot(kind='hist', bins=30)
plt.title('Общая плата за месяц по тарифу "ultra"') 
plt.xlabel('Общая плата') 
plt.ylabel('Частота')
plt.show()

# %%
df[df['tariff'] == 'smart']['total_paid'].plot(kind='hist', bins=30)
plt.title('Общая плата за месяц по тарифу "smart"') 
plt.xlabel('Общая плата') 
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# По этим 4 графикам снова видим такую же картину, в целом почти всегда пользователям тарифа ультра хватает услуг по тарифу и лишь незначительная часть доплачивает сверх тарифа, а у смарт таких людей, которые превышают лимит по тем или иным параметрам достаточно много.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Очень детально проверили наш анализ пользователей, выводы абсолютно логичны и даже придраться не к чему 😊👍
#
# Предлагаю приступить к проверке наших гипотез.
#
# </div>

# %% [markdown]
# ## Этап 4. Проверка гипотез

# %% [markdown]
# ### Задачи: ###
# 1. Проверить различается ли средняя выручка пользователей тарифов «Ультра» и «Смарт»;
# 2. Проверить отличается ли средняя выручка пользователей из Москвы от выручки пользователей из других регионов;

# %% [markdown]
# ### Задача 1: ###
# Т.к. наши выборки по двум тарифам и по городам (Москва и не Москва) независимы между собой, и нам надо проверить гипотезу о равенстве средних двух совокупностей, то используем метод "scipy.stats.ttest_ind".
# В нашем случае нулевая и альтернативная гипотезы будут следующие:
#
# 1. H0: Средняя выручка тарифов "Ультра" и "Смарт" не различается
# 2. H1: Средняя выручка тарифов "Ультра" и "Смарт" различается

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Гипотезы сформулированы верно.
#
#
# **Best practies:**
#
# Перед проверкой гипотезы рекомендую проверить дисперсии выборок, чтобы корректно определить атрибут `equal_val` в Т–тесте.
#
# В том числе стоит визуализировать распределение каждой выборки, чтобы определить нормальное ли у них распределение или нет.
#
# </div>

# %%
ultra = df[df['tariff'] == 'ultra']
display(ultra.head())
# Out:
#    user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 0     1000    August                 418.0                            52.0
# 1     1000  December                 341.0                            46.0
# 2     1000      July                 346.0                            47.0
# 3     1000      June                 187.0                            43.0
# 4     1000       May                 164.0                            22.0
#
#    total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# 0                          81.0                     14055.93   52        NaT
# 1                          70.0                      9817.61   52        NaT
# 2                          75.0                     14003.64   52        NaT
# 3                          60.0                     23233.77   52        NaT
# 4                          22.0                      2253.49   52        NaT
#
# ...

# %%
ultra = ultra['total_paid']
display(ultra.head())
# Out:
# 0    1950.0
# 1    1950.0
# 2    1950.0
# 3    1950.0
# 4    1950.0
# Name: total_paid, dtype: float64

# %%
smart = df[df['tariff'] == 'smart']
display(smart.head())
# Out:
#     user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 8      1001  December                 430.0                            63.0
# 9      1001  November                 444.0                            59.0
# 10     1002    August                 294.0                            42.0
# 11     1002  December                 242.0                            33.0
# 12     1002      July                 219.0                            26.0
#
#     total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# 8                            0.0                     14036.66   41        NaT
# 9                            0.0                     18429.34   41        NaT
# 10                          13.0                     20319.26   59        NaT
# 11                          12.0                     18113.73   59        NaT
# 12                          11.0                     17580.10   59        NaT
#
# ...

# %%
smart = smart['total_paid']
display(smart.head())
# Out:
# 8      550.0
# 9     1149.0
# 10    1518.0
# 11    1087.0
# 12     983.0
# Name: total_paid, dtype: float64

# %% [markdown]
# Для начала сохраняем в перменную названия тарифа выборку всех пользователей по каждому из тарифов. Далее отбираем только интересующий нас параметр, т.е. выручку, которая хранится в переменной 'total_paid'.

# %%
alpha = .05

# %%
results = st.ttest_ind(ultra, smart)
print('p-значение: ', results.pvalue)
# Out:
# p-значение:  2.5716849878978304e-182

# %%
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Отвергаем нулевую гипотезу

# %% [markdown]
# Таким образом, получили результат - маловероятно, что средняя выручка двух тарифов не различается. (В принципе мы видели это и раньше, показатели по средней и медианной выручке у двух тарифов существенно отличались)

# %% [markdown]
# ### Задача 2:###
# Здесь нулевая и альтернативная гипотезы следующие:
#
# 1. H0: средняя выручка пользователей из Москвы не отличается от выручки пользователей из других регионов;
# 2. H1: средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов;

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Гипотезы сформулированы верно.
#
# </div>

# %%
df['city'].unique()
# Out:
# array(['Краснодар', 'Москва', 'Стерлитамак', 'Новокузнецк',
#        'Набережные Челны', 'Ульяновск', 'Челябинск', 'Пермь', 'Тюмень',
#        'Самара', 'Санкт-Петербург', 'Иваново', 'Чебоксары', 'Омск', 'Уфа',
#        'Томск', 'Чита', 'Мурманск', 'Петрозаводск', 'Тверь',
#        'Екатеринбург', 'Махачкала', 'Вологда', 'Череповец', 'Ярославль',
#        'Сочи', 'Хабаровск', 'Ставрополь', 'Рязань', 'Улан-Удэ', 'Тула',
#        'Саратов', 'Ростов-на-Дону', 'Казань', 'Иркутск', 'Курск',
#        'Калуга', 'Якутск', 'Астрахань', 'Химки', 'Владикавказ',
#        'Волгоград', 'Саранск', 'Ижевск', 'Новосибирск', 'Брянск',
#        'Тольятти', 'Нижний Тагил', 'Орёл', 'Белгород', 'Воронеж',
#        'Курган', 'Барнаул', 'Красноярск', 'Архангельск', 'Липецк',
#        'Кемерово', 'Киров', 'Сургут', 'Пенза', 'Волжский', 'Магнитогорск',
#        'Нижний Новгород', 'Кострома', 'Владивосток', 'Тамбов', 'Балашиха',
#        'Севастополь', 'Калининград', 'Оренбург', 'Смоленск',
# ...

# %%
def moscow_or_not(row):
    if row['city'] == 'Москва':
        return 'Москва'
    else:
        return 'Не Москва'
    
df['moscow_or_other'] = df.apply(moscow_or_not, axis=1)
display(df.head(20))
# Out:
#     user_id      month  month_calls_duration  total_amount_of_calls_in_month  \
# 0      1000     August                 418.0                            52.0
# 1      1000   December                 341.0                            46.0
# 2      1000       July                 346.0                            47.0
# 3      1000       June                 187.0                            43.0
# 4      1000        May                 164.0                            22.0
# 5      1000   November                 344.0                            43.0
# 6      1000    October                 363.0                            57.0
# 7      1000  September                 478.0                            58.0
# 8      1001   December                 430.0                            63.0
# 9      1001   November                 444.0                            59.0
# 10     1002     August                 294.0                            42.0
# ...

# %%
moscow = df[df['moscow_or_other'] == 'Москва']
display(moscow.head())
# Out:
#     user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 8      1001  December                 430.0                            63.0
# 9      1001  November                 444.0                            59.0
# 17     1003    August                 392.0                            55.0
# 18     1003  December                 822.0                           108.0
# 19     1003  November                 844.0                           115.0
#
#     total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# 8                            0.0                     14036.66   41        NaT
# 9                            0.0                     18429.34   41        NaT
# 17                          37.0                      8565.21   23        NaT
# 18                          75.0                     10121.53   23        NaT
# 19                          94.0                     11356.89   23        NaT
#
# ...

# %%
moscow = moscow['total_paid']
display(moscow.head())
# Out:
# 8      550.0
# 9     1149.0
# 17    1950.0
# 18    1950.0
# 19    1950.0
# Name: total_paid, dtype: float64

# %%
not_moscow = df[df['moscow_or_other'] == 'Не Москва']
display(not_moscow.head())
# Out:
#    user_id     month  month_calls_duration  total_amount_of_calls_in_month  \
# 0     1000    August                 418.0                            52.0
# 1     1000  December                 341.0                            46.0
# 2     1000      July                 346.0                            47.0
# 3     1000      June                 187.0                            43.0
# 4     1000       May                 164.0                            22.0
#
#    total_amount_of_sms_in_month  total_amount_of_mb_in_month  age churn_date  \
# 0                          81.0                     14055.93   52        NaT
# 1                          70.0                      9817.61   52        NaT
# 2                          75.0                     14003.64   52        NaT
# 3                          60.0                     23233.77   52        NaT
# 4                          22.0                      2253.49   52        NaT
#
# ...

# %%
not_moscow = not_moscow['total_paid']
display(not_moscow.head())
# Out:
# 0    1950.0
# 1    1950.0
# 2    1950.0
# 3    1950.0
# 4    1950.0
# Name: total_paid, dtype: float64

# %%
alpha = .05 
results = st.ttest_ind(moscow, not_moscow)
print('p-значение: ', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.5153735337451972
# Не получилось отвергнуть нулевую гипотезу

# %%
df.groupby('moscow_or_other').agg({'total_paid':['median','mean','var','std']})
# Out:
#                 total_paid
#                     median         mean            var         std
# moscow_or_other
# Москва              1728.0  1514.800327  547408.546951  739.870629
# Не Москва           1539.0  1491.823665  633623.678733  796.004823

# %% [markdown]
# Результат проверки второй гипотезы - не получилось отвергнуть нулевую гипотезу, соответственно, нет оснований полагать, что средняя выручка от пользователей из Москвы отличается от средней выручки от пользователей не из Москвы. (По таблице также видно, что эти показатели лежат близко друг к другу)

# %% [markdown]
# ## Общий вывод ##

# %% [markdown]
# 1. В среднем пользователи двух тарифов совершают 62 звонка в месяц, общая длительность которых 463 минуты, 38 сообщений, около 17 Гбайт интернета. Но также встречаются выбросы:  например, среди пользователей обоих тарифов встречаются люди, которые не использую те или иные услуги (интернет, звонки, сообщения), или, наоборот, встречаются пользователи, которые за месяц наговорили 1727 минут.
# 3. В среднем пользователи тарифа "ультра" тратят в месяц 532  минуты на разговоры, отправляют 38 сообщений и используют 19308 Мбайт интернета. Большинство пользователей этого тарифа укладываются в свой пакет услуг, и лишь незначительная часть превышает их и приносит прибыль сверх тарифной платы.
# 4. Что касается тарифа «смарт», то здесь в среднем пользователи тратят в месяц 435 минут на разговоры, отправляют 28 сообщения и используют 16507 Мбайт интернета. При этом большинство пользователей (более 75%) не укладываются в пакет услуг по тарифу и доплачивает за пользование дополнительными пакетами.
# 5. Интересно, что многие пользователи тарифа «ультра» не используют бОльшую часть своего пакета: (например, третий квартиль – 75% по длительности разговоров за месяц только 773 минуты из 3000 доступных, т.е. используется менее 25% от возможного; в смс сообщениях третий квартиль равен 79 сообщениям из 1000 доступных, т.е. это менее 8%; единственный показатель, в котором третий квартиль достаточно близко к значению лимита тарифа – интернет – примерно 26,5 Гбайт из 30 доступных).
# 6. С тарифом «смарт» все иначе: пользователи чаще выходят за лимит пакета услуг, т.к. эти границы достаточно низкие – 500 минут, 15 Гбайт и 50 сообщений, а третий квартиль соответственно равен 560 минутам, 20 Гбайт и 51 сообщению.
# 7. Также в ходе статистической проверки гипотез, было выявлено, что средняя выручка двух тарифов различается, а проживание клиента в Москве или в другом городе не влияет на среднюю выручку от этих пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
# Успехов тебе в новых проектах!
#
# </div>
